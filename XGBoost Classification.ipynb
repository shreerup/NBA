# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('train.csv')
campaign_data = pd.read_csv('campaign_data.csv')
coupon_item_mapping = pd.read_csv('coupon_item_mapping.csv')
customer_demographics = pd.read_csv('customer_demographics.csv')
customer_transaction_data = pd.read_csv('customer_transaction_data.csv')
item_data = pd.read_csv('item_data.csv')
test_data = pd.read_csv('test.csv')

# %%
ti = pd.merge(customer_transaction_data, item_data, on='item_id', how='left')

# %%
ti['category'] = ti['category'].replace({'Packaged Meat': 'Gift Cards', 'Bakery': 'Digital Gold', 'Dairy, Juices & Snacks': 'Electricity Bill', 'Natural Products': 'Jewelry', 'Meat': 'Insurance'})
desired_categories = ['Gift Cards', 'Insurance', 'Digital Gold', 'Electricity Bill', 'Jewelry', 'Pharmaceutical', 'Grocery']
ti = ti[ti['category'].isin(desired_categories)]
ti['category'] = ti['category'].replace('Pharmaceutical', 'Pharmacy')

# %%
ti['category'].value_counts()
# Out:
# Grocery             942176
# Pharmacy            155245
# Gift Cards           66110
# Jewelry              52981
# Insurance            23056
# Electricity Bill     20465
# Digital Gold         18218
# Name: category, dtype: int64

# %%
category_avg = ti.groupby('category').agg({'selling_price': 'mean', 'other_discount': 'mean', 'coupon_discount': 'mean'})
category_avg
# Out:
#                   selling_price  other_discount  coupon_discount
# category
# Digital Gold         117.956141       -9.962247        -0.102159
# Electricity Bill     107.100653      -12.712502        -0.237140
# Gift Cards           134.488465      -35.495811        -0.350940
# Grocery               91.521779      -17.476031        -0.599109
# Insurance            202.534326      -39.835106        -0.066664
# Jewelry               86.902200       -7.616079        -0.148649
# Pharmacy             147.324046      -11.652425        -1.090751

# %%
np.random.seed(42)
grocery_rows = ti[ti['category'] == 'Grocery']
num_rows_to_delete = int(0.8 * len(grocery_rows))
rows_to_delete = np.random.choice(grocery_rows.index, size=num_rows_to_delete, replace=False)
ti = ti.drop(rows_to_delete)

# %%
jewelry_rows = ti['category'] == 'Jewelry'
ti.loc[jewelry_rows, 'selling_price'] *= 80
ti.loc[jewelry_rows, 'other_discount'] *= 80
ti.loc[jewelry_rows, 'coupon_discount'] *= 80

# %%
g_rows = ti['category'] == 'Grocery'
ti.loc[g_rows, 'selling_price'] *= 3
ti.loc[g_rows, 'other_discount'] *= 3
ti.loc[g_rows, 'coupon_discount'] *= 3

# %%
gi_rows = ti['category'] == 'Gift Cards'
ti.loc[gi_rows, 'selling_price'] *= 8
ti.loc[gi_rows, 'other_discount'] *= 8
ti.loc[gi_rows, 'coupon_discount'] *= 8

# %%
ei_rows = ti['category'] == 'Electricity Bill'
ti.loc[ei_rows, 'selling_price'] *= 12
ti.loc[ei_rows, 'other_discount'] *= 12
ti.loc[ei_rows, 'coupon_discount'] *= 12

# %%
i_rows = ti['category'] == 'Insurance'
ti.loc[i_rows, 'selling_price'] *= 25
ti.loc[i_rows, 'other_discount'] *= 25
ti.loc[i_rows, 'coupon_discount'] *= 25

# %%
dg_rows = ti['category'] == 'Digital Gold'
ti.loc[dg_rows, 'selling_price'] *= 80
ti.loc[dg_rows, 'other_discount'] *= 80
ti.loc[dg_rows, 'coupon_discount'] *= 80

# %%
ti['category'].value_counts()
# Out:
# Grocery             188436
# Pharmacy            155245
# Gift Cards           66110
# Jewelry              52981
# Insurance            23056
# Electricity Bill     20465
# Digital Gold         18218
# Name: category, dtype: int64

# %%
category_avg = ti.groupby('category').agg({'selling_price': 'mean', 'other_discount': 'mean', 'coupon_discount': 'mean'})
category_avg
# Out:
#                   selling_price  other_discount  coupon_discount
# category
# Digital Gold        9436.491250     -796.979778        -8.172708
# Electricity Bill    1285.207840     -152.550028        -2.845674
# Gift Cards          1075.907721     -283.966485        -2.807522
# Grocery              274.329262      -52.534853        -1.803596
# Insurance           5063.358139     -995.877646        -1.666594
# Jewelry             6952.176033     -609.286318       -11.891886
# Pharmacy             147.324046      -11.652425        -1.090751

# %%
ti = ti.drop(['brand', 'brand_type'], axis=1)

# %%
ti = ti.sort_values(by=['customer_id'])
ti
# Out:
#                date  customer_id  item_id  quantity  selling_price  \
# 193877   2012-05-17            1    28590         1       11369.60
# 417865   2012-08-12            1    52350         1         307.77
# 848584   2013-01-10            1     5525         1        1136.96
# 848585   2013-01-10            1     6089         1          74.45
# 848587   2013-01-10            1     7492         1          63.76
# ...             ...          ...      ...       ...            ...
# 894526   2013-01-26         1582    25356         1         852.00
# 649060   2012-11-02         1582     7512         1          76.58
# 649061   2012-11-02         1582    15958         1          89.05
# 487505   2012-09-04         1582    10944         1          41.67
# 1093108  2013-04-09         1582    10491         1         135.00
#
#          other_discount  coupon_discount      category
# 193877             0.00             0.00  Digital Gold
# 417865          -204.09             0.00       Grocery
# 848584             0.00             0.00    Gift Cards
# 848585           -19.23           -26.71      Pharmacy
# 848587             0.00             0.00      Pharmacy
# ...                 ...              ...           ...
# 894526             0.00             0.00    Gift Cards
# 649060             0.00             0.00      Pharmacy
# 649061           -31.70             0.00      Pharmacy
# 487505             0.00             0.00       Grocery
# 1093108            0.00             0.00      Pharmacy
#
# [524511 rows x 8 columns]

# %%
ti['customer_id'].nunique()
# Out:
# 1582

# %%
train_campaign = pd.merge(train_data, campaign_data, on='campaign_id', how='left')

# %%
train_campaign = train_campaign.sort_values(by=['customer_id', 'start_date'])
train_campaign
# Out:
#            id  campaign_id  coupon_id  customer_id  redemption_status  \
# 51584   84658           29        416            1                  0
# 67721  111193           29        458            1                  0
# 58566   96238           29        868            1                  0
# 61514  101106           29        643            1                  0
# 64676  106173           29        982            1                  0
# ...       ...          ...        ...          ...                ...
# 51364   84284           13        890         1582                  0
# 21030   34529           13        160         1582                  0
# 17547   28849           13        151         1582                  0
# 73895  121355           13        114         1582                  0
# 55387   91060           13        561         1582                  0
#
#       campaign_type start_date  end_date
# 51584             Y   08/10/12  30/11/12
# 67721             Y   08/10/12  30/11/12
# 58566             Y   08/10/12  30/11/12
# 61514             Y   08/10/12  30/11/12
# 64676             Y   08/10/12  30/11/12
# ...             ...        ...       ...
# 51364             X   19/05/13  05/07/13
# 21030             X   19/05/13  05/07/13
# 17547             X   19/05/13  05/07/13
# 73895             X   19/05/13  05/07/13
# 55387             X   19/05/13  05/07/13
#
# [78369 rows x 8 columns]

# %%
train_campaign_item = pd.merge(train_campaign, coupon_item_mapping, on='coupon_id', how='left')

# %%
train_campaign_item
# Out:
#              id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0         84658           29        416            1                  0
# 1         84658           29        416            1                  0
# 2         84658           29        416            1                  0
# 3         84658           29        416            1                  0
# 4         84658           29        416            1                  0
# ...         ...          ...        ...          ...                ...
# 6420689  121355           13        114         1582                  0
# 6420690  121355           13        114         1582                  0
# 6420691  121355           13        114         1582                  0
# 6420692   91060           13        561         1582                  0
# 6420693   91060           13        561         1582                  0
#
#         campaign_type start_date  end_date  item_id
# 0                   Y   08/10/12  30/11/12      933
# 1                   Y   08/10/12  30/11/12      942
# 2                   Y   08/10/12  30/11/12     6443
# 3                   Y   08/10/12  30/11/12    10545
# 4                   Y   08/10/12  30/11/12    14500
# ...               ...        ...       ...      ...
# 6420689             X   19/05/13  05/07/13     7721
# 6420690             X   19/05/13  05/07/13    40025
# 6420691             X   19/05/13  05/07/13    17985
# 6420692             X   19/05/13  05/07/13    57307
# 6420693             X   19/05/13  05/07/13    64678
#
# [6420694 rows x 9 columns]

# %%
ti
# Out:
#                date  customer_id  item_id  quantity  selling_price  \
# 193877   2012-05-17            1    28590         1       11369.60
# 417865   2012-08-12            1    52350         1         307.77
# 848584   2013-01-10            1     5525         1        1136.96
# 848585   2013-01-10            1     6089         1          74.45
# 848587   2013-01-10            1     7492         1          63.76
# ...             ...          ...      ...       ...            ...
# 894526   2013-01-26         1582    25356         1         852.00
# 649060   2012-11-02         1582     7512         1          76.58
# 649061   2012-11-02         1582    15958         1          89.05
# 487505   2012-09-04         1582    10944         1          41.67
# 1093108  2013-04-09         1582    10491         1         135.00
#
#          other_discount  coupon_discount      category
# 193877             0.00             0.00  Digital Gold
# 417865          -204.09             0.00       Grocery
# 848584             0.00             0.00    Gift Cards
# 848585           -19.23           -26.71      Pharmacy
# 848587             0.00             0.00      Pharmacy
# ...                 ...              ...           ...
# 894526             0.00             0.00    Gift Cards
# 649060             0.00             0.00      Pharmacy
# 649061           -31.70             0.00      Pharmacy
# 487505             0.00             0.00       Grocery
# 1093108            0.00             0.00      Pharmacy
#
# [524511 rows x 8 columns]

# %%
merge = pd.merge(ti, train_campaign_item, on=['customer_id', 'item_id'], how='inner')

# %%
merge
# Out:
#              date  customer_id  item_id  quantity  selling_price  \
# 0      2013-01-10            1     5525         1        1136.96
# 1      2012-04-04            1    58644         2         534.30
# 2      2012-05-26            1    58644         1         319.50
# 3      2012-04-21            1    58644         1         267.15
# 4      2012-06-14            1    58644         1         319.50
# ...           ...          ...      ...       ...            ...
# 62647  2013-01-26         1582    11712         2          29.92
# 62648  2012-11-02         1582    32830         1         640.80
# 62649  2013-01-26         1582    59550         2          29.92
# 62650  2013-01-26         1582    25559         4          59.84
# 62651  2013-04-09         1582    10491         1         135.00
#
#        other_discount  coupon_discount    category      id  campaign_id  \
# 0                0.00             0.00  Gift Cards  102278           13
# 1             -211.59             0.00     Grocery   94621            8
# 2              -53.43             0.00     Grocery   94621            8
# 3             -105.78             0.00     Grocery   94621            8
# 4              -53.43             0.00     Grocery   94621            8
# ...               ...              ...         ...     ...          ...
# 62647            0.00             0.00    Pharmacy   16149           10
# 62648          -35.62           -35.62    Pharmacy   82908           10
# 62649            0.00             0.00    Pharmacy   16149           10
# 62650            0.00             0.00    Pharmacy   16149           10
# 62651            0.00             0.00    Pharmacy   44511            9
#
#        coupon_id  redemption_status campaign_type start_date  end_date
# 0             24                  0             X   19/05/13  05/07/13
# 1            772                  1             X   16/02/13  05/04/13
# 2            772                  1             X   16/02/13  05/04/13
# 3            772                  1             X   16/02/13  05/04/13
# 4            772                  1             X   16/02/13  05/04/13
# ...          ...                ...           ...        ...       ...
# 62647        934                  0             Y   08/04/13  10/05/13
# 62648        662                  0             Y   08/04/13  10/05/13
# 62649        934                  0             Y   08/04/13  10/05/13
# 62650        934                  0             Y   08/04/13  10/05/13
# 62651        691                  0             Y   11/03/13  12/04/13
#
# [62652 rows x 15 columns]

# %%
merge = merge.sort_values(by=['customer_id', 'start_date'])
merge
# Out:
#              date  customer_id  item_id  quantity  selling_price  \
# 55     2012-10-18            1    56179         1         362.25
# 56     2012-11-20            1    56179         1         362.25
# 57     2013-02-04            1    56179         1         362.25
# 58     2012-04-18            1    56179         1         308.82
# 59     2013-02-16            1    56179         1         362.25
# ...           ...          ...      ...       ...            ...
# 62628  2013-05-22         1582    22340         2         382.56
# 62641  2013-04-23         1582    28623         4        1282.32
# 62651  2013-04-09         1582    10491         1         135.00
# 62630  2013-03-25         1582    56886         1         267.15
# 62605  2013-06-25         1582     5012         2         106.86
#
#        other_discount  coupon_discount  category     id  campaign_id  \
# 55             -32.07             0.00   Grocery  96238           29
# 56             -32.07             0.00   Grocery  96238           29
# 57             -32.07             0.00   Grocery  96238           29
# 58             -85.50             0.00   Grocery  96238           29
# 59             -32.07             0.00   Grocery  96238           29
# ...               ...              ...       ...    ...          ...
# 62628          -64.11             0.00   Grocery  47762            9
# 62641         -718.11             0.00   Grocery  24249            9
# 62651            0.00             0.00  Pharmacy  44511            9
# 62630          -95.10          -106.86   Grocery   1641            8
# 62605          -61.98             0.00   Grocery  15132           13
#
#        coupon_id  redemption_status campaign_type start_date  end_date
# 55           868                  0             Y   08/10/12  30/11/12
# 56           868                  0             Y   08/10/12  30/11/12
# 57           868                  0             Y   08/10/12  30/11/12
# 58           868                  0             Y   08/10/12  30/11/12
# 59           868                  0             Y   08/10/12  30/11/12
# ...          ...                ...           ...        ...       ...
# 62628        578                  0             Y   11/03/13  12/04/13
# 62641        705                  0             Y   11/03/13  12/04/13
# 62651        691                  0             Y   11/03/13  12/04/13
# 62630        674                  1             X   16/02/13  05/04/13
# 62605        982                  0             X   19/05/13  05/07/13
#
# [62652 rows x 15 columns]

# %%
cashback_p = pd.read_excel('target_data_custom_modified.xlsx')

# %%
tab = cashback_p
tab['category'] = tab['category'].replace({'Packaged Meat': 'Gift Cards', 'Bakery': 'Digital Gold', 'Dairy, Juices & Snacks': 'Electricity Bill', 'Natural Products': 'Jewelry', 'Meat': 'Insurance'})
desired_categories = ['Gift Cards', 'Insurance', 'Digital Gold', 'Electricity Bill', 'Jewelry', 'Pharmaceutical', 'Grocery']
tab = tab[tab['category'].isin(desired_categories)]

# %%
tab['category'] = tab['category'].replace('Pharmaceutical', 'Pharmacy')
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_10284\2577117585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tab['category'] = tab['category'].replace('Pharmaceutical', 'Pharmacy')

# %%
tab = tab.sort_values(by=['customer_id', 'start_date'])
tab
# Out:
#            id  campaign_id  coupon_id  customer_id start_date   end_date  \
# 3178     4674           29        597            1 2012-10-08 2012-11-30
# 4583     6741           29        896            1 2012-10-08 2012-11-30
# 7055    10185           29        696            1 2012-10-08 2012-11-30
# 11335   16239           29        750            1 2012-10-08 2012-11-30
# 13256   19022           29        443            1 2012-10-08 2012-11-30
# ...       ...          ...        ...          ...        ...        ...
# 63041   91060           13        561         1582 2013-05-19 2013-07-05
# 71907  103994           13        766         1582 2013-05-19 2013-07-05
# 83829  121355           13        114         1582 2013-05-19 2013-07-05
# 84366  122144           13        511         1582 2013-05-19 2013-07-05
# 86122  124625           13        142         1582 2013-05-19 2013-07-05
#
#                category  redemption_status  cashback percentage  \
# 3178            Grocery                  0             0.491759
# 4583   Electricity Bill                  0             0.302298
# 7055   Electricity Bill                  0             0.302298
# 11335           Grocery                  0             0.302298
# 13256           Grocery                  0             0.166667
# ...                 ...                ...                  ...
# 63041          Pharmacy                  0             0.302298
# 71907           Grocery                  0             0.283554
# 83829           Grocery                  0             0.302298
# 84366           Grocery                  0             0.314590
# 86122           Grocery                  0             0.302298
#
#        null reassignment
# 3178                   0
# 4583                   1
# 7055                   1
# 11335                  1
# 13256                  0
# ...                  ...
# 63041                  1
# 71907                  0
# 83829                  1
# 84366                  0
# 86122                  1
#
# [81525 rows x 10 columns]

# %%
merge['cashback percentage']=-1*merge['coupon_discount']/(merge['selling_price'])

# %%
merge['cashback percentage'].nunique()
# Out:
# 608

# %%
merge['redemption_status'].value_counts()
# Out:
# 0    56101
# 1     6551
# Name: redemption_status, dtype: int64

# %%
merge
# Out:
#              date  customer_id  item_id  quantity  selling_price  \
# 0      2013-01-10            1     5525         1        1136.96
# 1      2012-04-04            1    58644         2         534.30
# 2      2012-05-26            1    58644         1         319.50
# 3      2012-04-21            1    58644         1         267.15
# 4      2012-06-14            1    58644         1         319.50
# ...           ...          ...      ...       ...            ...
# 62647  2013-01-26         1582    11712         2          29.92
# 62648  2012-11-02         1582    32830         1         640.80
# 62649  2013-01-26         1582    59550         2          29.92
# 62650  2013-01-26         1582    25559         4          59.84
# 62651  2013-04-09         1582    10491         1         135.00
#
#        other_discount  coupon_discount    category      id  campaign_id  \
# 0                0.00             0.00  Gift Cards  102278           13
# 1             -211.59             0.00     Grocery   94621            8
# 2              -53.43             0.00     Grocery   94621            8
# 3             -105.78             0.00     Grocery   94621            8
# 4              -53.43             0.00     Grocery   94621            8
# ...               ...              ...         ...     ...          ...
# 62647            0.00             0.00    Pharmacy   16149           10
# 62648          -35.62           -35.62    Pharmacy   82908           10
# 62649            0.00             0.00    Pharmacy   16149           10
# 62650            0.00             0.00    Pharmacy   16149           10
# 62651            0.00             0.00    Pharmacy   44511            9
#
#        coupon_id  redemption_status campaign_type start_date  end_date  \
# 0             24                  0             X   19/05/13  05/07/13
# 1            772                  1             X   16/02/13  05/04/13
# 2            772                  1             X   16/02/13  05/04/13
# 3            772                  1             X   16/02/13  05/04/13
# 4            772                  1             X   16/02/13  05/04/13
# ...          ...                ...           ...        ...       ...
# 62647        934                  0             Y   08/04/13  10/05/13
# 62648        662                  0             Y   08/04/13  10/05/13
# 62649        934                  0             Y   08/04/13  10/05/13
# 62650        934                  0             Y   08/04/13  10/05/13
# 62651        691                  0             Y   11/03/13  12/04/13
#
#        cashback percentage
# 0                -0.000000
# 1                -0.000000
# 2                -0.000000
# 3                -0.000000
# 4                -0.000000
# ...                    ...
# 62647            -0.000000
# 62648             0.055587
# 62649            -0.000000
# 62650            -0.000000
# 62651            -0.000000
#
# [62652 rows x 16 columns]

# %%
merge_del = merge.drop(['date', 'item_id', 'quantity', 'id', 'campaign_id', 'coupon_id', 'campaign_type', 'cashback percentage'], axis=1)

# %%
merge_del = merge_del.sort_values(by=['customer_id', 'start_date'])

# %%
xg = pd.read_excel('XGBoost.xlsx')

# %%
xg = xg.drop(['Unnamed: 0'], axis=1)

# %%
xg
# Out:
#        customer_id start_date  cashback_value_1m  \
# 0                1 2012-10-08            4296.95
# 1                1 2012-10-08            4296.95
# 2                1 2012-10-08            4296.95
# 3                1 2012-10-08            4296.95
# 4                1 2012-10-08            4296.95
# ...            ...        ...                ...
# 61254         1580 2013-02-16             213.72
# 61255         1580 2013-05-19             375.09
# 61256         1580 2013-05-19             375.09
# 61257         1580 2013-05-19             375.09
# 61258         1581 2013-02-16               0.00
#
#       last_reward_transaction_category_1m  \
# 0                                Pharmacy
# 1                                Pharmacy
# 2                                Pharmacy
# 3                                Pharmacy
# 4                                Pharmacy
# ...                                   ...
# 61254                            Pharmacy
# 61255                          Gift Cards
# 61256                          Gift Cards
# 61257                          Gift Cards
# 61258                            Pharmacy
#
#       reward_transaction_category_frequent_1m  coupons_issued_1m  \
# 0                                     Grocery                 32
# 1                                     Grocery                 32
# 2                                     Grocery                 32
# 3                                     Grocery                 32
# 4                                     Grocery                 32
# ...                                       ...                ...
# 61254                                Pharmacy                 11
# 61255                                 Grocery                  3
# 61256                                 Grocery                  3
# 61257                                 Grocery                  3
# 61258                                Pharmacy                  1
#
#        coupons_collected_1m  coupons_redeemed_1m  net_redemption_rate_1m  \
# 0                        16                    7                 0.21875
# 1                        16                    7                 0.21875
# 2                        16                    7                 0.21875
# 3                        16                    7                 0.21875
# 4                        16                    7                 0.21875
# ...                     ...                  ...                     ...
# 61254                     4                    0                 0.00000
# 61255                     2                    0                 0.00000
# 61256                     2                    0                 0.00000
# 61257                     2                    0                 0.00000
# 61258                     0                    0                 0.00000
#
#       first_use_case_1m  ... Pharmacy_value_1m  Jewelry_value_1m  \
# 0          Digital Gold  ...            900.83            5699.2
# 1          Digital Gold  ...            900.83            5699.2
# 2          Digital Gold  ...            900.83            5699.2
# 3          Digital Gold  ...            900.83            5699.2
# 4          Digital Gold  ...            900.83            5699.2
# ...                 ...  ...               ...               ...
# 61254           Jewelry  ...            661.10            5670.4
# 61255          Pharmacy  ...             81.57               0.0
# 61256          Pharmacy  ...             81.57               0.0
# 61257          Pharmacy  ...             81.57               0.0
# 61258        Gift Cards  ...              0.00               0.0
#
#        Insurance_value_1m  Gift cards_value_1m  \
# 0                     0.0              7029.92
# 1                     0.0              7029.92
# 2                     0.0              7029.92
# 3                     0.0              7029.92
# 4                     0.0              7029.92
# ...                   ...                  ...
# 61254                 0.0              1136.96
# 61255                 0.0                 0.00
# 61256                 0.0                 0.00
# 61257                 0.0                 0.00
# 61258                 0.0              1476.08
#
#        Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                              4274.4           3117.06                  0
# 1                              4274.4           3117.06                  0
# 2                              4274.4           3117.06                  0
# 3                              4274.4           3117.06                  0
# 4                              4274.4           3117.06                  0
# ...                               ...               ...                ...
# 61254                             0.0            753.36                  1
# 61255                             0.0            667.86                  0
# 61256                             0.0            667.86                  0
# 61257                             0.0            667.86                  0
# 61258                             0.0              0.00                  0
#
#        days_difference    category  cashback percentage
# 0                   18     Grocery             0.196654
# 1                   18     Grocery             0.467270
# 2                   18     Grocery             0.211676
# 3                   18     Grocery             0.286542
# 4                   18     Grocery             0.302298
# ...                ...         ...                  ...
# 61254               30     Jewelry             0.478304
# 61255               25    Pharmacy             0.302298
# 61256               25     Grocery             0.339219
# 61257               25     Grocery             0.301381
# 61258               30  Gift Cards             0.200405
#
# [61259 rows x 50 columns]

# %%
xg['redemption_status'] = merge_del['redemption_status'].head(61259)

# %%
xg['redemption_status'].value_counts()
# Out:
# 0.0    55094
# 1.0     6143
# Name: redemption_status, dtype: int64

# %%
xg
# Out:
#        customer_id start_date  cashback_value_1m  \
# 0                1 2012-10-08            4296.95
# 1                1 2012-10-08            4296.95
# 2                1 2012-10-08            4296.95
# 3                1 2012-10-08            4296.95
# 4                1 2012-10-08            4296.95
# ...            ...        ...                ...
# 61254         1580 2013-02-16             213.72
# 61255         1580 2013-05-19             375.09
# 61256         1580 2013-05-19             375.09
# 61257         1580 2013-05-19             375.09
# 61258         1581 2013-02-16               0.00
#
#       last_reward_transaction_category_1m  \
# 0                                Pharmacy
# 1                                Pharmacy
# 2                                Pharmacy
# 3                                Pharmacy
# 4                                Pharmacy
# ...                                   ...
# 61254                            Pharmacy
# 61255                          Gift Cards
# 61256                          Gift Cards
# 61257                          Gift Cards
# 61258                            Pharmacy
#
#       reward_transaction_category_frequent_1m  coupons_issued_1m  \
# 0                                     Grocery                 32
# 1                                     Grocery                 32
# 2                                     Grocery                 32
# 3                                     Grocery                 32
# 4                                     Grocery                 32
# ...                                       ...                ...
# 61254                                Pharmacy                 11
# 61255                                 Grocery                  3
# 61256                                 Grocery                  3
# 61257                                 Grocery                  3
# 61258                                Pharmacy                  1
#
#        coupons_collected_1m  coupons_redeemed_1m  net_redemption_rate_1m  \
# 0                        16                    7                 0.21875
# 1                        16                    7                 0.21875
# 2                        16                    7                 0.21875
# 3                        16                    7                 0.21875
# 4                        16                    7                 0.21875
# ...                     ...                  ...                     ...
# 61254                     4                    0                 0.00000
# 61255                     2                    0                 0.00000
# 61256                     2                    0                 0.00000
# 61257                     2                    0                 0.00000
# 61258                     0                    0                 0.00000
#
#       first_use_case_1m  ... Pharmacy_value_1m  Jewelry_value_1m  \
# 0          Digital Gold  ...            900.83            5699.2
# 1          Digital Gold  ...            900.83            5699.2
# 2          Digital Gold  ...            900.83            5699.2
# 3          Digital Gold  ...            900.83            5699.2
# 4          Digital Gold  ...            900.83            5699.2
# ...                 ...  ...               ...               ...
# 61254           Jewelry  ...            661.10            5670.4
# 61255          Pharmacy  ...             81.57               0.0
# 61256          Pharmacy  ...             81.57               0.0
# 61257          Pharmacy  ...             81.57               0.0
# 61258        Gift Cards  ...              0.00               0.0
#
#        Insurance_value_1m  Gift cards_value_1m  \
# 0                     0.0              7029.92
# 1                     0.0              7029.92
# 2                     0.0              7029.92
# 3                     0.0              7029.92
# 4                     0.0              7029.92
# ...                   ...                  ...
# 61254                 0.0              1136.96
# 61255                 0.0                 0.00
# 61256                 0.0                 0.00
# 61257                 0.0                 0.00
# 61258                 0.0              1476.08
#
#        Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                              4274.4           3117.06                0.0
# 1                              4274.4           3117.06                1.0
# 2                              4274.4           3117.06                1.0
# 3                              4274.4           3117.06                1.0
# 4                              4274.4           3117.06                1.0
# ...                               ...               ...                ...
# 61254                             0.0            753.36                0.0
# 61255                             0.0            667.86                0.0
# 61256                             0.0            667.86                0.0
# 61257                             0.0            667.86                0.0
# 61258                             0.0              0.00                0.0
#
#        days_difference    category  cashback percentage
# 0                   18     Grocery             0.196654
# 1                   18     Grocery             0.467270
# 2                   18     Grocery             0.211676
# 3                   18     Grocery             0.286542
# 4                   18     Grocery             0.302298
# ...                ...         ...                  ...
# 61254               30     Jewelry             0.478304
# 61255               25    Pharmacy             0.302298
# 61256               25     Grocery             0.339219
# 61257               25     Grocery             0.301381
# 61258               30  Gift Cards             0.200405
#
# [61259 rows x 50 columns]

# %%
# Define the conditions for Digital Gold and Jewelry categories
condition_dg_high_cb = (xg['category'] == 'Digital Gold') & (xg['cashback percentage'] > 0.5)
condition_dg_low_cb = (xg['category'] == 'Digital Gold') & (xg['cashback percentage'] < 0.5) & (xg['cashback percentage'] > 0.25)
condition_jewelry_high_cb = (xg['category'] == 'Jewelry') & (xg['cashback percentage'] > 0.5)
condition_jewelry_low_cb = (xg['category'] == 'Jewelry') & (xg['cashback percentage'] < 0.5) & (xg['cashback percentage'] > 0.25)

# Modify the redemption_status based on the conditions
xg.loc[condition_dg_high_cb, 'redemption_status'] = xg.loc[condition_dg_high_cb, 'redemption_status'].sample(frac=0.4)
xg.loc[condition_dg_low_cb, 'redemption_status'] = xg.loc[condition_dg_low_cb, 'redemption_status'].sample(frac=0.2)
xg.loc[condition_jewelry_high_cb, 'redemption_status'] = xg.loc[condition_jewelry_high_cb, 'redemption_status'].sample(frac=0.4)
xg.loc[condition_jewelry_low_cb, 'redemption_status'] = xg.loc[condition_jewelry_low_cb, 'redemption_status'].sample(frac=0.2)

# %%
xg['redemption_status'].value_counts()
# Out:
# 0.0    50899
# 1.0     5668
# Name: redemption_status, dtype: int64

# %%
xg
# Out:
#        customer_id start_date  cashback_value_1m  \
# 0                1 2012-10-08            4296.95
# 1                1 2012-10-08            4296.95
# 2                1 2012-10-08            4296.95
# 3                1 2012-10-08            4296.95
# 4                1 2012-10-08            4296.95
# ...            ...        ...                ...
# 61254         1580 2013-02-16             213.72
# 61255         1580 2013-05-19             375.09
# 61256         1580 2013-05-19             375.09
# 61257         1580 2013-05-19             375.09
# 61258         1581 2013-02-16               0.00
#
#       last_reward_transaction_category_1m  \
# 0                                Pharmacy
# 1                                Pharmacy
# 2                                Pharmacy
# 3                                Pharmacy
# 4                                Pharmacy
# ...                                   ...
# 61254                            Pharmacy
# 61255                          Gift Cards
# 61256                          Gift Cards
# 61257                          Gift Cards
# 61258                            Pharmacy
#
#       reward_transaction_category_frequent_1m  coupons_issued_1m  \
# 0                                     Grocery                 32
# 1                                     Grocery                 32
# 2                                     Grocery                 32
# 3                                     Grocery                 32
# 4                                     Grocery                 32
# ...                                       ...                ...
# 61254                                Pharmacy                 11
# 61255                                 Grocery                  3
# 61256                                 Grocery                  3
# 61257                                 Grocery                  3
# 61258                                Pharmacy                  1
#
#        coupons_collected_1m  coupons_redeemed_1m  net_redemption_rate_1m  \
# 0                        16                    7                 0.21875
# 1                        16                    7                 0.21875
# 2                        16                    7                 0.21875
# 3                        16                    7                 0.21875
# 4                        16                    7                 0.21875
# ...                     ...                  ...                     ...
# 61254                     4                    0                 0.00000
# 61255                     2                    0                 0.00000
# 61256                     2                    0                 0.00000
# 61257                     2                    0                 0.00000
# 61258                     0                    0                 0.00000
#
#       first_use_case_1m  ... Pharmacy_value_1m  Jewelry_value_1m  \
# 0          Digital Gold  ...            900.83            5699.2
# 1          Digital Gold  ...            900.83            5699.2
# 2          Digital Gold  ...            900.83            5699.2
# 3          Digital Gold  ...            900.83            5699.2
# 4          Digital Gold  ...            900.83            5699.2
# ...                 ...  ...               ...               ...
# 61254           Jewelry  ...            661.10            5670.4
# 61255          Pharmacy  ...             81.57               0.0
# 61256          Pharmacy  ...             81.57               0.0
# 61257          Pharmacy  ...             81.57               0.0
# 61258        Gift Cards  ...              0.00               0.0
#
#        Insurance_value_1m  Gift cards_value_1m  \
# 0                     0.0              7029.92
# 1                     0.0              7029.92
# 2                     0.0              7029.92
# 3                     0.0              7029.92
# 4                     0.0              7029.92
# ...                   ...                  ...
# 61254                 0.0              1136.96
# 61255                 0.0                 0.00
# 61256                 0.0                 0.00
# 61257                 0.0                 0.00
# 61258                 0.0              1476.08
#
#        Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                              4274.4           3117.06                0.0
# 1                              4274.4           3117.06                1.0
# 2                              4274.4           3117.06                1.0
# 3                              4274.4           3117.06                1.0
# 4                              4274.4           3117.06                1.0
# ...                               ...               ...                ...
# 61254                             0.0            753.36                NaN
# 61255                             0.0            667.86                0.0
# 61256                             0.0            667.86                0.0
# 61257                             0.0            667.86                0.0
# 61258                             0.0              0.00                0.0
#
#        days_difference    category  cashback percentage
# 0                   18     Grocery             0.196654
# 1                   18     Grocery             0.467270
# 2                   18     Grocery             0.211676
# 3                   18     Grocery             0.286542
# 4                   18     Grocery             0.302298
# ...                ...         ...                  ...
# 61254               30     Jewelry             0.478304
# 61255               25    Pharmacy             0.302298
# 61256               25     Grocery             0.339219
# 61257               25     Grocery             0.301381
# 61258               30  Gift Cards             0.200405
#
# [61259 rows x 50 columns]

# %%
# Define the conditions for Gift Cards category
condition_gc_high_cb = (xg['category'] == 'Gift Cards') & (xg['cashback percentage'] > 0.6)
condition_gc_low_cb = (xg['category'] == 'Gift Cards') & (xg['cashback percentage'] < 0.6) & (xg['cashback percentage'] > 0.25)

# Modify the redemption_status based on the conditions
xg.loc[condition_gc_high_cb, 'redemption_status'] = xg.loc[condition_gc_high_cb].sample(frac=0.6)['redemption_status']
xg.loc[condition_gc_low_cb, 'redemption_status'] = xg.loc[condition_gc_low_cb].sample(frac=0.3)['redemption_status']

# %%
xg['redemption_status'].value_counts()
# Out:
# 0.0    59094
# 1.0     2143
# Name: redemption_status, dtype: int64

# %%
# Define the condition for redemption_status = 1.0
condition_rs_1 = (xg['redemption_status'] == 1.0)

# Randomly select 4000 rows that satisfy the condition and modify the redemption_status
random_indices = xg.loc[condition_rs_1].sample(n=4000).index
xg.loc[random_indices, 'redemption_status'] = 0.0

# %%
xg.head(25)
# Out:
#     customer_id start_date  cashback_value_1m  \
# 0             1 2012-10-08            4296.95
# 1             1 2012-10-08            4296.95
# 2             1 2012-10-08            4296.95
# 3             1 2012-10-08            4296.95
# 4             1 2012-10-08            4296.95
# 5             1 2012-10-08            4296.95
# 6             1 2012-10-08            4296.95
# 7             1 2012-10-08            4296.95
# 8             1 2012-10-08            4296.95
# 9             1 2012-10-08            4296.95
# 10            1 2012-10-08            4296.95
# 11            1 2012-10-08            4296.95
# 12            1 2012-10-08            4296.95
# 13            1 2012-10-08            4296.95
# 14            1 2012-10-08            4296.95
# 15            1 2012-10-08            4296.95
# 16            1 2012-10-08            4296.95
# 17            1 2012-10-08            4296.95
# 18            1 2012-10-08            4296.95
# 19            1 2012-10-08            4296.95
# 20            1 2012-10-08            4296.95
# 21            1 2012-10-08            4296.95
# 22            1 2012-10-08            4296.95
# 23            1 2012-10-08            4296.95
# 24            1 2012-10-08            4296.95
#
#    last_reward_transaction_category_1m  \
# 0                             Pharmacy
# 1                             Pharmacy
# 2                             Pharmacy
# 3                             Pharmacy
# 4                             Pharmacy
# 5                             Pharmacy
# 6                             Pharmacy
# 7                             Pharmacy
# 8                             Pharmacy
# 9                             Pharmacy
# 10                            Pharmacy
# 11                            Pharmacy
# 12                            Pharmacy
# 13                            Pharmacy
# 14                            Pharmacy
# 15                            Pharmacy
# 16                            Pharmacy
# 17                            Pharmacy
# 18                            Pharmacy
# 19                            Pharmacy
# 20                            Pharmacy
# 21                            Pharmacy
# 22                            Pharmacy
# 23                            Pharmacy
# 24                            Pharmacy
#
#    reward_transaction_category_frequent_1m  coupons_issued_1m  \
# 0                                  Grocery                 32
# 1                                  Grocery                 32
# 2                                  Grocery                 32
# 3                                  Grocery                 32
# 4                                  Grocery                 32
# 5                                  Grocery                 32
# 6                                  Grocery                 32
# 7                                  Grocery                 32
# 8                                  Grocery                 32
# 9                                  Grocery                 32
# 10                                 Grocery                 32
# 11                                 Grocery                 32
# 12                                 Grocery                 32
# 13                                 Grocery                 32
# 14                                 Grocery                 32
# 15                                 Grocery                 32
# 16                                 Grocery                 32
# 17                                 Grocery                 32
# 18                                 Grocery                 32
# 19                                 Grocery                 32
# 20                                 Grocery                 32
# 21                                 Grocery                 32
# 22                                 Grocery                 32
# 23                                 Grocery                 32
# 24                                 Grocery                 32
#
#     coupons_collected_1m  coupons_redeemed_1m  net_redemption_rate_1m  \
# 0                     16                    7                 0.21875
# 1                     16                    7                 0.21875
# 2                     16                    7                 0.21875
# 3                     16                    7                 0.21875
# 4                     16                    7                 0.21875
# 5                     16                    7                 0.21875
# 6                     16                    7                 0.21875
# 7                     16                    7                 0.21875
# 8                     16                    7                 0.21875
# 9                     16                    7                 0.21875
# 10                    16                    7                 0.21875
# 11                    16                    7                 0.21875
# 12                    16                    7                 0.21875
# 13                    16                    7                 0.21875
# 14                    16                    7                 0.21875
# 15                    16                    7                 0.21875
# 16                    16                    7                 0.21875
# 17                    16                    7                 0.21875
# 18                    16                    7                 0.21875
# 19                    16                    7                 0.21875
# 20                    16                    7                 0.21875
# 21                    16                    7                 0.21875
# 22                    16                    7                 0.21875
# 23                    16                    7                 0.21875
# 24                    16                    7                 0.21875
#
#    first_use_case_1m  ... Pharmacy_value_1m  Jewelry_value_1m  \
# 0       Digital Gold  ...            900.83            5699.2
# 1       Digital Gold  ...            900.83            5699.2
# 2       Digital Gold  ...            900.83            5699.2
# 3       Digital Gold  ...            900.83            5699.2
# 4       Digital Gold  ...            900.83            5699.2
# 5       Digital Gold  ...            900.83            5699.2
# 6       Digital Gold  ...            900.83            5699.2
# 7       Digital Gold  ...            900.83            5699.2
# 8       Digital Gold  ...            900.83            5699.2
# 9       Digital Gold  ...            900.83            5699.2
# 10      Digital Gold  ...            900.83            5699.2
# 11      Digital Gold  ...            900.83            5699.2
# 12      Digital Gold  ...            900.83            5699.2
# 13      Digital Gold  ...            900.83            5699.2
# 14      Digital Gold  ...            900.83            5699.2
# 15      Digital Gold  ...            900.83            5699.2
# 16      Digital Gold  ...            900.83            5699.2
# 17      Digital Gold  ...            900.83            5699.2
# 18      Digital Gold  ...            900.83            5699.2
# 19      Digital Gold  ...            900.83            5699.2
# 20      Digital Gold  ...            900.83            5699.2
# 21      Digital Gold  ...            900.83            5699.2
# 22      Digital Gold  ...            900.83            5699.2
# 23      Digital Gold  ...            900.83            5699.2
# 24      Digital Gold  ...            900.83            5699.2
#
#     Insurance_value_1m  Gift cards_value_1m  Digital gold purchase_value_1m  \
# 0                  0.0              7029.92                          4274.4
# 1                  0.0              7029.92                          4274.4
# 2                  0.0              7029.92                          4274.4
# 3                  0.0              7029.92                          4274.4
# 4                  0.0              7029.92                          4274.4
# 5                  0.0              7029.92                          4274.4
# 6                  0.0              7029.92                          4274.4
# 7                  0.0              7029.92                          4274.4
# 8                  0.0              7029.92                          4274.4
# 9                  0.0              7029.92                          4274.4
# 10                 0.0              7029.92                          4274.4
# 11                 0.0              7029.92                          4274.4
# 12                 0.0              7029.92                          4274.4
# 13                 0.0              7029.92                          4274.4
# 14                 0.0              7029.92                          4274.4
# 15                 0.0              7029.92                          4274.4
# 16                 0.0              7029.92                          4274.4
# 17                 0.0              7029.92                          4274.4
# 18                 0.0              7029.92                          4274.4
# 19                 0.0              7029.92                          4274.4
# 20                 0.0              7029.92                          4274.4
# 21                 0.0              7029.92                          4274.4
# 22                 0.0              7029.92                          4274.4
# 23                 0.0              7029.92                          4274.4
# 24                 0.0              7029.92                          4274.4
#
#     Grocery_value_1m  redemption_status  days_difference    category  \
# 0            3117.06                0.0               18     Grocery
# 1            3117.06                1.0               18     Grocery
# 2            3117.06                1.0               18     Grocery
# 3            3117.06                0.0               18     Grocery
# 4            3117.06                0.0               18     Grocery
# 5            3117.06                1.0               18     Grocery
# 6            3117.06                1.0               18     Grocery
# 7            3117.06                0.0               18     Grocery
# 8            3117.06                0.0               18     Grocery
# 9            3117.06                0.0               18     Grocery
# 10           3117.06                0.0               18     Grocery
# 11           3117.06                0.0               18    Pharmacy
# 12           3117.06                0.0               18    Pharmacy
# 13           3117.06                0.0               18    Pharmacy
# 14           3117.06                0.0               18    Pharmacy
# 15           3117.06                0.0               18    Pharmacy
# 16           3117.06                0.0               18    Pharmacy
# 17           3117.06                0.0               18    Pharmacy
# 18           3117.06                0.0               18    Pharmacy
# 19           3117.06                0.0               18    Pharmacy
# 20           3117.06                0.0               18    Pharmacy
# 21           3117.06                0.0               18  Gift Cards
# 22           3117.06                0.0               18  Gift Cards
# 23           3117.06                0.0               18  Gift Cards
# 24           3117.06                0.0               18  Gift Cards
#
#     cashback percentage
# 0              0.196654
# 1              0.467270
# 2              0.211676
# 3              0.286542
# 4              0.302298
# 5              0.242263
# 6              0.218340
# 7              0.346027
# 8              0.250000
# 9              0.222222
# 10             0.500000
# 11             0.491759
# 12             0.436680
# 13             0.182153
# 14             0.302298
# 15             0.100203
# 16             0.302298
# 17             0.714400
# 18             0.257073
# 19             1.000000
# 20             1.000000
# 21             0.302298
# 22             0.302298
# 23             0.302298
# 24             0.166667
#
# [25 rows x 50 columns]

# %%
# Define the conditions for cashback percentage ranges
condition_cb_high = xg['cashback percentage'] > 0.85
condition_cb_low = (xg['cashback percentage'] < 0.85) & (xg['cashback percentage'] > 0.6)

# Randomly select rows and modify the redemption_status based on the conditions
high_indices = xg.loc[condition_cb_high].sample(frac=0.55).index
low_indices = xg.loc[condition_cb_low].sample(frac=0.35).index

xg.loc[high_indices, 'redemption_status'] = 1.0
xg.loc[low_indices, 'redemption_status'] = 1.0

# Define the condition for cashback percentage range
condition_cb = (xg['cashback percentage'] < 0.6) & (xg['cashback percentage'] > 0.4)

# Randomly select rows and modify the redemption_status based on the condition
indices = xg.loc[condition_cb].sample(frac=0.15).index
xg.loc[indices, 'redemption_status'] = 1.0

# %%
xg['redemption_status'].value_counts()
# Out:
# 0.0    58647
# 1.0     2612
# Name: redemption_status, dtype: int64

# %%
xg['redemption_status'] = xg['redemption_status'].fillna(0.0)

# %%
xg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61259 entries, 0 to 61258
# Data columns (total 50 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   customer_id                                    61259 non-null  int64
#  1   start_date                                     61259 non-null  datetime64[ns]
#  2   cashback_value_1m                              61259 non-null  float64
#  3   last_reward_transaction_category_1m            61259 non-null  object
#  4   reward_transaction_category_frequent_1m        61259 non-null  object
#  5   coupons_issued_1m                              61259 non-null  int64
#  6   coupons_collected_1m                           61259 non-null  int64
#  7   coupons_redeemed_1m                            61259 non-null  int64
#  8   net_redemption_rate_1m                         61259 non-null  float64
#  9   first_use_case_1m                              61259 non-null  object
#  10  last_use_case_1m                               61259 non-null  object
#  11  success_orders_Electricity Bill_1m             61259 non-null  int64
#  12  success_orders_Pharmacy_1m                     61259 non-null  int64
#  13  success_orders_Jewelry_1m                      61259 non-null  int64
#  14  success_orders_Insurance_1m                    61259 non-null  int64
#  15  success_orders_Gift Cards_1m                   61259 non-null  int64
#  16  success_orders_Digital Gold_1m                 61259 non-null  int64
#  17  success_orders_Grocery_1m                      61259 non-null  int64
#  18  Electricity bill pay_cashback_1m               61259 non-null  float64
#  19  Pharmacy_cashback_1m                           61259 non-null  float64
#  20  Jewelry_cashback_1m                            61259 non-null  float64
#  21  Insurance_cashback_1m                          61259 non-null  float64
#  22  Gift cards_cashback_1m                         61259 non-null  float64
#  23  Digital gold purchase_cashback_1m              61259 non-null  float64
#  24  Grocery_cashback_1m                            61259 non-null  float64
#  25  total_redeemed_value_electricity_bill_1m       61259 non-null  float64
#  26  total_redeemed_value_pharmacy_1m               61259 non-null  float64
#  27  total_redeemed_value_jewelry_1m                61259 non-null  float64
#  28  total_redeemed_value_insurance_1m              61259 non-null  float64
#  29  total_redeemed_value_gift_cards_1m             61259 non-null  float64
#  30  total_redeemed_value_digital_gold_purchase_1m  61259 non-null  float64
#  31  total_redeemed_value_grocery_1m                61259 non-null  float64
#  32  Electricity bill pay_txn_count_1m              61259 non-null  int64
#  33  Pharmacy_txn_count_1m                          61259 non-null  int64
#  34  Jewelry_txn_count_1m                           61259 non-null  int64
#  35  Insurance_txn_count_1m                         61259 non-null  int64
#  36  Gift cards_txn_count_1m                        61259 non-null  int64
#  37  Digital gold purchase_txn_count_1m             61259 non-null  int64
#  38  Grocery_txn_count_1m                           61259 non-null  int64
#  39  Electricity bill pay_value_1m                  61259 non-null  float64
#  40  Pharmacy_value_1m                              61259 non-null  float64
#  41  Jewelry_value_1m                               61259 non-null  float64
#  42  Insurance_value_1m                             61259 non-null  float64
#  43  Gift cards_value_1m                            61259 non-null  float64
#  44  Digital gold purchase_value_1m                 61259 non-null  float64
#  45  Grocery_value_1m                               61259 non-null  float64
#  46  redemption_status                              61259 non-null  float64
#  47  days_difference                                61259 non-null  int64
#  48  category                                       61259 non-null  object
#  49  cashback percentage                            61259 non-null  float64
# dtypes: datetime64[ns](1), float64(25), int64(19), object(5)
# memory usage: 23.4+ MB

# %%
condition_rs_1 = (xg['redemption_status'] == 1.0)

# Randomly select 4000 rows that satisfy the condition and modify the redemption_status
random_indices = xg.loc[condition_rs_1].sample(n=1000).index
xg.loc[random_indices, 'redemption_status'] = 0.0

# %%
xg.head(23)
# Out:
#     customer_id start_date  cashback_value_1m  \
# 0             1 2012-10-08            4296.95
# 1             1 2012-10-08            4296.95
# 2             1 2012-10-08            4296.95
# 3             1 2012-10-08            4296.95
# 4             1 2012-10-08            4296.95
# 5             1 2012-10-08            4296.95
# 6             1 2012-10-08            4296.95
# 7             1 2012-10-08            4296.95
# 8             1 2012-10-08            4296.95
# 9             1 2012-10-08            4296.95
# 10            1 2012-10-08            4296.95
# 11            1 2012-10-08            4296.95
# 12            1 2012-10-08            4296.95
# 13            1 2012-10-08            4296.95
# 14            1 2012-10-08            4296.95
# 15            1 2012-10-08            4296.95
# 16            1 2012-10-08            4296.95
# 17            1 2012-10-08            4296.95
# 18            1 2012-10-08            4296.95
# 19            1 2012-10-08            4296.95
# 20            1 2012-10-08            4296.95
# 21            1 2012-10-08            4296.95
# 22            1 2012-10-08            4296.95
#
#    last_reward_transaction_category_1m  \
# 0                             Pharmacy
# 1                             Pharmacy
# 2                             Pharmacy
# 3                             Pharmacy
# 4                             Pharmacy
# 5                             Pharmacy
# 6                             Pharmacy
# 7                             Pharmacy
# 8                             Pharmacy
# 9                             Pharmacy
# 10                            Pharmacy
# 11                            Pharmacy
# 12                            Pharmacy
# 13                            Pharmacy
# 14                            Pharmacy
# 15                            Pharmacy
# 16                            Pharmacy
# 17                            Pharmacy
# 18                            Pharmacy
# 19                            Pharmacy
# 20                            Pharmacy
# 21                            Pharmacy
# 22                            Pharmacy
#
#    reward_transaction_category_frequent_1m  coupons_issued_1m  \
# 0                                  Grocery                 32
# 1                                  Grocery                 32
# 2                                  Grocery                 32
# 3                                  Grocery                 32
# 4                                  Grocery                 32
# 5                                  Grocery                 32
# 6                                  Grocery                 32
# 7                                  Grocery                 32
# 8                                  Grocery                 32
# 9                                  Grocery                 32
# 10                                 Grocery                 32
# 11                                 Grocery                 32
# 12                                 Grocery                 32
# 13                                 Grocery                 32
# 14                                 Grocery                 32
# 15                                 Grocery                 32
# 16                                 Grocery                 32
# 17                                 Grocery                 32
# 18                                 Grocery                 32
# 19                                 Grocery                 32
# 20                                 Grocery                 32
# 21                                 Grocery                 32
# 22                                 Grocery                 32
#
#     coupons_collected_1m  coupons_redeemed_1m  net_redemption_rate_1m  \
# 0                     16                    7                 0.21875
# 1                     16                    7                 0.21875
# 2                     16                    7                 0.21875
# 3                     16                    7                 0.21875
# 4                     16                    7                 0.21875
# 5                     16                    7                 0.21875
# 6                     16                    7                 0.21875
# 7                     16                    7                 0.21875
# 8                     16                    7                 0.21875
# 9                     16                    7                 0.21875
# 10                    16                    7                 0.21875
# 11                    16                    7                 0.21875
# 12                    16                    7                 0.21875
# 13                    16                    7                 0.21875
# 14                    16                    7                 0.21875
# 15                    16                    7                 0.21875
# 16                    16                    7                 0.21875
# 17                    16                    7                 0.21875
# 18                    16                    7                 0.21875
# 19                    16                    7                 0.21875
# 20                    16                    7                 0.21875
# 21                    16                    7                 0.21875
# 22                    16                    7                 0.21875
#
#    first_use_case_1m  ... Pharmacy_value_1m  Jewelry_value_1m  \
# 0       Digital Gold  ...            900.83            5699.2
# 1       Digital Gold  ...            900.83            5699.2
# 2       Digital Gold  ...            900.83            5699.2
# 3       Digital Gold  ...            900.83            5699.2
# 4       Digital Gold  ...            900.83            5699.2
# 5       Digital Gold  ...            900.83            5699.2
# 6       Digital Gold  ...            900.83            5699.2
# 7       Digital Gold  ...            900.83            5699.2
# 8       Digital Gold  ...            900.83            5699.2
# 9       Digital Gold  ...            900.83            5699.2
# 10      Digital Gold  ...            900.83            5699.2
# 11      Digital Gold  ...            900.83            5699.2
# 12      Digital Gold  ...            900.83            5699.2
# 13      Digital Gold  ...            900.83            5699.2
# 14      Digital Gold  ...            900.83            5699.2
# 15      Digital Gold  ...            900.83            5699.2
# 16      Digital Gold  ...            900.83            5699.2
# 17      Digital Gold  ...            900.83            5699.2
# 18      Digital Gold  ...            900.83            5699.2
# 19      Digital Gold  ...            900.83            5699.2
# 20      Digital Gold  ...            900.83            5699.2
# 21      Digital Gold  ...            900.83            5699.2
# 22      Digital Gold  ...            900.83            5699.2
#
#     Insurance_value_1m  Gift cards_value_1m  Digital gold purchase_value_1m  \
# 0                  0.0              7029.92                          4274.4
# 1                  0.0              7029.92                          4274.4
# 2                  0.0              7029.92                          4274.4
# 3                  0.0              7029.92                          4274.4
# 4                  0.0              7029.92                          4274.4
# 5                  0.0              7029.92                          4274.4
# 6                  0.0              7029.92                          4274.4
# 7                  0.0              7029.92                          4274.4
# 8                  0.0              7029.92                          4274.4
# 9                  0.0              7029.92                          4274.4
# 10                 0.0              7029.92                          4274.4
# 11                 0.0              7029.92                          4274.4
# 12                 0.0              7029.92                          4274.4
# 13                 0.0              7029.92                          4274.4
# 14                 0.0              7029.92                          4274.4
# 15                 0.0              7029.92                          4274.4
# 16                 0.0              7029.92                          4274.4
# 17                 0.0              7029.92                          4274.4
# 18                 0.0              7029.92                          4274.4
# 19                 0.0              7029.92                          4274.4
# 20                 0.0              7029.92                          4274.4
# 21                 0.0              7029.92                          4274.4
# 22                 0.0              7029.92                          4274.4
#
#     Grocery_value_1m  redemption_status  days_difference    category  \
# 0            3117.06                0.0               18     Grocery
# 1            3117.06                0.0               18     Grocery
# 2            3117.06                1.0               18     Grocery
# 3            3117.06                0.0               18     Grocery
# 4            3117.06                0.0               18     Grocery
# 5            3117.06                1.0               18     Grocery
# 6            3117.06                1.0               18     Grocery
# 7            3117.06                0.0               18     Grocery
# 8            3117.06                0.0               18     Grocery
# 9            3117.06                0.0               18     Grocery
# 10           3117.06                0.0               18     Grocery
# 11           3117.06                0.0               18    Pharmacy
# 12           3117.06                0.0               18    Pharmacy
# 13           3117.06                0.0               18    Pharmacy
# 14           3117.06                0.0               18    Pharmacy
# 15           3117.06                0.0               18    Pharmacy
# 16           3117.06                0.0               18    Pharmacy
# 17           3117.06                0.0               18    Pharmacy
# 18           3117.06                0.0               18    Pharmacy
# 19           3117.06                1.0               18    Pharmacy
# 20           3117.06                0.0               18    Pharmacy
# 21           3117.06                0.0               18  Gift Cards
# 22           3117.06                0.0               18  Gift Cards
#
#     cashback percentage
# 0              0.196654
# 1              0.467270
# 2              0.211676
# 3              0.286542
# 4              0.302298
# 5              0.242263
# 6              0.218340
# 7              0.346027
# 8              0.250000
# 9              0.222222
# 10             0.500000
# 11             0.491759
# 12             0.436680
# 13             0.182153
# 14             0.302298
# 15             0.100203
# 16             0.302298
# 17             0.714400
# 18             0.257073
# 19             1.000000
# 20             1.000000
# 21             0.302298
# 22             0.302298
#
# [23 rows x 50 columns]

# %%
xg.to_excel('coupon_redemption_data_for_xgboost.xlsx')

# %%
xgb = xg.drop_duplicates()

# %%
xgb['redemption_status'].value_counts()
# Out:
# 0.0    38279
# 1.0     2400
# Name: redemption_status, dtype: int64

# %%
xgb.to_excel('coupon_redemption_data_xgboost.xlsx')

# %%
df = pd.read_excel('coupon_redemption_data_for_xgboost.xlsx')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#    customer_id start_date  cashback_value_1m  \
# 0            1 2012-10-08            4296.95
# 1            1 2012-10-08            4296.95
# 2            1 2012-10-08            4296.95
# 3            1 2012-10-08            4296.95
# 4            1 2012-10-08            4296.95
#
#   last_reward_transaction_category_1m reward_transaction_category_frequent_1m  \
# 0                            Pharmacy                                 Grocery
# 1                            Pharmacy                                 Grocery
# 2                            Pharmacy                                 Grocery
# 3                            Pharmacy                                 Grocery
# 4                            Pharmacy                                 Grocery
#
#    coupons_issued_1m  coupons_collected_1m  coupons_redeemed_1m  \
# 0                 32                    16                    7
# 1                 32                    16                    7
# 2                 32                    16                    7
# 3                 32                    16                    7
# 4                 32                    16                    7
#
#    net_redemption_rate_1m first_use_case_1m  ... Pharmacy_value_1m  \
# 0                 0.21875      Digital Gold  ...            900.83
# 1                 0.21875      Digital Gold  ...            900.83
# 2                 0.21875      Digital Gold  ...            900.83
# 3                 0.21875      Digital Gold  ...            900.83
# 4                 0.21875      Digital Gold  ...            900.83
#
#    Jewelry_value_1m  Insurance_value_1m  Gift cards_value_1m  \
# 0            5699.2                 0.0              7029.92
# 1            5699.2                 0.0              7029.92
# 2            5699.2                 0.0              7029.92
# 3            5699.2                 0.0              7029.92
# 4            5699.2                 0.0              7029.92
#
#    Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                          4274.4           3117.06                  0
# 1                          4274.4           3117.06                  0
# 2                          4274.4           3117.06                  1
# 3                          4274.4           3117.06                  0
# 4                          4274.4           3117.06                  0
#
#    days_difference  category  cashback percentage
# 0               18   Grocery             0.196654
# 1               18   Grocery             0.467270
# 2               18   Grocery             0.211676
# 3               18   Grocery             0.286542
# 4               18   Grocery             0.302298
#
# [5 rows x 50 columns]

# %%
import numpy as

# %%
import numpy as np

# Set the random seed for reproducibility
np.random.seed(1)

# Generate random values for cashback_percentage
df['cashback_percentage'] = np.where(df['redemption_status'] == 0, np.random.uniform(0, 0.3, len(df)), np.random.uniform(0.15, 0.5, len(df)))

# Round the values to 5 decimal places
df['cashback_percentage'] = df['cashback_percentage'].round(5)

# %%
df1 = df

# %%
df1.head()
# Out:
#    customer_id start_date  cashback_value_1m  \
# 0            1 2012-10-08            4296.95
# 1            1 2012-10-08            4296.95
# 2            1 2012-10-08            4296.95
# 3            1 2012-10-08            4296.95
# 4            1 2012-10-08            4296.95
#
#   last_reward_transaction_category_1m reward_transaction_category_frequent_1m  \
# 0                            Pharmacy                                 Grocery
# 1                            Pharmacy                                 Grocery
# 2                            Pharmacy                                 Grocery
# 3                            Pharmacy                                 Grocery
# 4                            Pharmacy                                 Grocery
#
#    coupons_issued_1m  coupons_collected_1m  coupons_redeemed_1m  \
# 0                 32                    16                    7
# 1                 32                    16                    7
# 2                 32                    16                    7
# 3                 32                    16                    7
# 4                 32                    16                    7
#
#    net_redemption_rate_1m first_use_case_1m  ... Jewelry_value_1m  \
# 0                 0.21875      Digital Gold  ...           5699.2
# 1                 0.21875      Digital Gold  ...           5699.2
# 2                 0.21875      Digital Gold  ...           5699.2
# 3                 0.21875      Digital Gold  ...           5699.2
# 4                 0.21875      Digital Gold  ...           5699.2
#
#    Insurance_value_1m  Gift cards_value_1m  Digital gold purchase_value_1m  \
# 0                 0.0              7029.92                          4274.4
# 1                 0.0              7029.92                          4274.4
# 2                 0.0              7029.92                          4274.4
# 3                 0.0              7029.92                          4274.4
# 4                 0.0              7029.92                          4274.4
#
#    Grocery_value_1m  redemption_status  days_difference  category  \
# 0           3117.06                  0               18   Grocery
# 1           3117.06                  0               18   Grocery
# 2           3117.06                  1               18   Grocery
# 3           3117.06                  0               18   Grocery
# 4           3117.06                  0               18   Grocery
#
#    cashback percentage  cashback_percentage
# 0             0.196654              0.12511
# 1             0.467270              0.21610
# 2             0.211676              0.25254
# 3             0.286542              0.09070
# 4             0.302298              0.04403
#
# [5 rows x 51 columns]

# %%
df1 = df1.drop(['cashback percentage'], axis=1)

# %%
df1.head()
# Out:
#    customer_id start_date  cashback_value_1m  \
# 0            1 2012-10-08            4296.95
# 1            1 2012-10-08            4296.95
# 2            1 2012-10-08            4296.95
# 3            1 2012-10-08            4296.95
# 4            1 2012-10-08            4296.95
#
#   last_reward_transaction_category_1m reward_transaction_category_frequent_1m  \
# 0                            Pharmacy                                 Grocery
# 1                            Pharmacy                                 Grocery
# 2                            Pharmacy                                 Grocery
# 3                            Pharmacy                                 Grocery
# 4                            Pharmacy                                 Grocery
#
#    coupons_issued_1m  coupons_collected_1m  coupons_redeemed_1m  \
# 0                 32                    16                    7
# 1                 32                    16                    7
# 2                 32                    16                    7
# 3                 32                    16                    7
# 4                 32                    16                    7
#
#    net_redemption_rate_1m first_use_case_1m  ... Pharmacy_value_1m  \
# 0                 0.21875      Digital Gold  ...            900.83
# 1                 0.21875      Digital Gold  ...            900.83
# 2                 0.21875      Digital Gold  ...            900.83
# 3                 0.21875      Digital Gold  ...            900.83
# 4                 0.21875      Digital Gold  ...            900.83
#
#    Jewelry_value_1m  Insurance_value_1m  Gift cards_value_1m  \
# 0            5699.2                 0.0              7029.92
# 1            5699.2                 0.0              7029.92
# 2            5699.2                 0.0              7029.92
# 3            5699.2                 0.0              7029.92
# 4            5699.2                 0.0              7029.92
#
#    Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                          4274.4           3117.06                  0
# 1                          4274.4           3117.06                  0
# 2                          4274.4           3117.06                  1
# 3                          4274.4           3117.06                  0
# 4                          4274.4           3117.06                  0
#
#    days_difference  category  cashback_percentage
# 0               18   Grocery              0.12511
# 1               18   Grocery              0.21610
# 2               18   Grocery              0.25254
# 3               18   Grocery              0.09070
# 4               18   Grocery              0.04403
#
# [5 rows x 50 columns]

# %%
df1['redemption_status'].value_counts()
# Out:
# 0    58743
# 1     2516
# Name: redemption_status, dtype: int64

# %%
df1.to_excel('cashback_data_xgboost.xlsx')

# %%
df1['cashback_percentage'].max()
# Out:
# 0.49991

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('cashback_data_xgboost.xlsx')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df['cashback_percentage'].max()
# Out:
# 0.49991

# %%
df['redemption_status'].value_counts()
# Out:
# 0    58743
# 1     2516
# Name: redemption_status, dtype: int64

# %%
df.head()
# Out:
#    customer_id start_date  cashback_value_1m  \
# 0            1 2012-10-08            4296.95
# 1            1 2012-10-08            4296.95
# 2            1 2012-10-08            4296.95
# 3            1 2012-10-08            4296.95
# 4            1 2012-10-08            4296.95
#
#   last_reward_transaction_category_1m reward_transaction_category_frequent_1m  \
# 0                            Pharmacy                                 Grocery
# 1                            Pharmacy                                 Grocery
# 2                            Pharmacy                                 Grocery
# 3                            Pharmacy                                 Grocery
# 4                            Pharmacy                                 Grocery
#
#    coupons_issued_1m  coupons_collected_1m  coupons_redeemed_1m  \
# 0                 32                    16                    7
# 1                 32                    16                    7
# 2                 32                    16                    7
# 3                 32                    16                    7
# 4                 32                    16                    7
#
#    net_redemption_rate_1m first_use_case_1m  ... Pharmacy_value_1m  \
# 0                 0.21875      Digital Gold  ...            900.83
# 1                 0.21875      Digital Gold  ...            900.83
# 2                 0.21875      Digital Gold  ...            900.83
# 3                 0.21875      Digital Gold  ...            900.83
# 4                 0.21875      Digital Gold  ...            900.83
#
#    Jewelry_value_1m  Insurance_value_1m  Gift cards_value_1m  \
# 0            5699.2                 0.0              7029.92
# 1            5699.2                 0.0              7029.92
# 2            5699.2                 0.0              7029.92
# 3            5699.2                 0.0              7029.92
# 4            5699.2                 0.0              7029.92
#
#    Digital gold purchase_value_1m  Grocery_value_1m  redemption_status  \
# 0                          4274.4           3117.06                  0
# 1                          4274.4           3117.06                  0
# 2                          4274.4           3117.06                  1
# 3                          4274.4           3117.06                  0
# 4                          4274.4           3117.06                  0
#
#    days_difference  category  cashback_percentage
# 0               18   Grocery              0.12511
# 1               18   Grocery              0.21610
# 2               18   Grocery              0.25254
# 3               18   Grocery              0.09070
# 4               18   Grocery              0.04403
#
# [5 rows x 50 columns]

# %%
import pandas as pd

# Assuming the data is stored in a pandas DataFrame called 'df'
# and the cashback percentage column is named 'cashback_percentage'

# Define the range intervals
intervals = [(0, 0.05), (0.05, 0.1), (0.1, 0.15), (0.15, 0.2), (0.2, 0.25), (0.25, 0.3), (0.3, 0.35), (0.35, 0.4), (0.4, 0.45), (0.45, 0.5)]

# Initialize a dictionary to store the counts for each range
counts = {}

# Iterate through the intervals
for interval in intervals:
    # Filter the rows that fall into the current interval
    filtered_rows = df[(df['cashback_percentage'] >= interval[0]) & (df['cashback_percentage'] < interval[1])]
    
    # Count the number of rows in the filtered DataFrame
    count = len(filtered_rows)
    
    # Store the count in the dictionary
    counts[interval] = count

# Print the counts for each range
for interval, count in counts.items():
    print(f"Total rows with cashback percentage between {interval[0]}-{interval[1]}: {count}")
# Out:
# Total rows with cashback percentage between 0-0.05: 9810
# Total rows with cashback percentage between 0.05-0.1: 9853
# Total rows with cashback percentage between 0.1-0.15: 9665
# Total rows with cashback percentage between 0.15-0.2: 10267
# Total rows with cashback percentage between 0.2-0.25: 10194
# Total rows with cashback percentage between 0.25-0.3: 10064
# Total rows with cashback percentage between 0.3-0.35: 364
# Total rows with cashback percentage between 0.35-0.4: 343
# Total rows with cashback percentage between 0.4-0.45: 326
# Total rows with cashback percentage between 0.45-0.5: 373

# %%
import random

# Set random seed for reproducibility
random.seed(42)

# Update redemption_status for rows with cashback_percentage between 0 and 0.05
df.loc[(df['cashback_percentage'] >= 0) & (df['cashback_percentage'] < 0.05), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0) & (df['cashback_percentage'] < 0.05), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.01 else 0)

# Update redemption_status for rows with cashback_percentage between 0.05 and 0.1
df.loc[(df['cashback_percentage'] >= 0.05) & (df['cashback_percentage'] < 0.1), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.05) & (df['cashback_percentage'] < 0.1), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.025 else 0)

# Update redemption_status for rows with cashback_percentage between 0.1 and 0.15
df.loc[(df['cashback_percentage'] >= 0.1) & (df['cashback_percentage'] < 0.15), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.1) & (df['cashback_percentage'] < 0.15), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.03 else 0)

# Update redemption_status for rows with cashback_percentage between 0.15 and 0.2
df.loc[(df['cashback_percentage'] >= 0.15) & (df['cashback_percentage'] < 0.2), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.15) & (df['cashback_percentage'] < 0.2), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.045 else 0)

# Update redemption_status for rows with cashback_percentage between 0.2 and 0.25
df.loc[(df['cashback_percentage'] >= 0.2) & (df['cashback_percentage'] < 0.25), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.2) & (df['cashback_percentage'] < 0.25), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.055 else 0)

# Update redemption_status for rows with cashback_percentage between 0.25 and 0.3
df.loc[(df['cashback_percentage'] >= 0.25) & (df['cashback_percentage'] < 0.3), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.25) & (df['cashback_percentage'] < 0.3), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.07 else 0)

# Update redemption_status for rows with cashback_percentage between 0.3 and 0.35
df.loc[(df['cashback_percentage'] >= 0.3) & (df['cashback_percentage'] < 0.35), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.3) & (df['cashback_percentage'] < 0.35), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.09 else 0)

# Update redemption_status for rows with cashback_percentage between 0.35 and 0.4
df.loc[(df['cashback_percentage'] >= 0.35) & (df['cashback_percentage'] < 0.4), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.35) & (df['cashback_percentage'] < 0.4), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.105 else 0)

# Update redemption_status for rows with cashback_percentage between 0.4 and 0.45
df.loc[(df['cashback_percentage'] >= 0.4) & (df['cashback_percentage'] < 0.45), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.4) & (df['cashback_percentage'] < 0.45), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.125 else 0)

# Update redemption_status for rows with cashback_percentage between 0.45 and 0.5
df.loc[(df['cashback_percentage'] >= 0.45) & (df['cashback_percentage'] < 0.5), 'redemption_status'] = \
    df.loc[(df['cashback_percentage'] >= 0.45) & (df['cashback_percentage'] < 0.5), 'redemption_status'].apply(
        lambda x: 1 if random.random() <= 0.14 else 0)

# %%
df['redemption_status'].value_counts()
# Out:
# 0    58699
# 1     2560
# Name: redemption_status, dtype: int64

# %%
df.to_csv('new_data.csv')
